# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras

from keras.layers import Dropout, Dense, Flatten, BatchNormalization, LeakyReLU, GlobalAveragePooling2D, Conv2D, MaxPool2D
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.xception import Xception

import cv2

from tqdm import tqdm
import os
import gc

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import warnings
warnings.filterwarnings("ignore")

# %%
test_directory = "C:/Users/joelb/OneDrive/Desktop/newproj/TEST"
train_directory = "C:/Users/joelb/OneDrive/Desktop/newproj/TRAIN.1"
# validation_directory = "../input/placenta-cell-data/PlacentaCell/validation"

# %%
img_size = (60,60)

# %%
def load_data(directory,img_size):
    images = []
    labels = []
    
    for i in tqdm(os.listdir(directory)):
        
        if i == 'B': label = 0
        elif i == 'N': label = 1
            
        for j in os.listdir(directory + '/' + i):
            
            image = cv2.imread(directory + '/' + i + '/' + j)
            resized_img = cv2.resize(image,img_size)
            
            images.append(resized_img / 255.0)
            labels.append(label)
            
    images = np.array(images, dtype = 'float32')
    labels = np.array(labels, dtype = 'int32')
    
    return images, labels

# %%
test_images, test_labels = load_data(test_directory,img_size)
train_images, train_labels = load_data(train_directory,img_size)
# val_images, val_labels = load_data(validation_directory,img_size)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [02:25<00:00, 72.72s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [09:15<00:00, 277.76s/it]

# %%
print(f'Shape of Test Data : {np.shape(test_images)} & Shape of Test Labels : {np.shape(test_labels)}')
print(f'Shape of Train Data : {np.shape(train_images)} & Shape of Train Label : {np.shape(train_labels)}')
# print(f'Shape of Validation Data : {np.shape(val_images)} & Shape of Validation Label : {np.shape(val_labels)}')
# Out:
# Shape of Test Data : (16726, 60, 60, 3) & Shape of Test Labels : (16726,)
# Shape of Train Data : (59922, 60, 60, 3) & Shape of Train Label : (59922,)

# %%
class_names = ['B','N']
fig, axes = plt.subplots(1,len(class_names))

for i in range(len(class_names)):
    dir_path = "C:/Users/joelb/OneDrive/Desktop/newproj/TRAIN.1" + '/' + class_names[i]
    img_path = dir_path + '/' + os.listdir(dir_path)[2]
    img = cv2.imread(img_path)
    resized_img = cv2.resize(img,img_size)
    axes[i].imshow(resized_img)
    axes[i].set_title(class_names[i])
    plt.tight_layout()

plt.show()

# %%
sns.countplot(x = train_labels)
plt.title("Class Distribution")
plt.xlabel("Class Names")
plt.ylabel("Count")
plt.show()

# %%
vgg16_model = Sequential()

vgg16_base = VGG16(
    include_top = False,
    weights = "imagenet",
    input_shape = (60,60,3),
    pooling = 'max'
)

print(f"Number of layers in Inception: {len(vgg16_base.layers)}")

for layer in vgg16_base.layers[:]:
    layer.trainable = False
    
for layer in vgg16_base.layers[16:]:
    layer.trainable = True
    
vgg16_model.add(vgg16_base)

vgg16_model.add(Flatten())

vgg16_model.add(Dense(units = 5, activation = 'softmax'))

vgg16_model.summary()

early_stopping = EarlyStopping( monitor = 'val_accuracy', mode = 'max', min_delta = 1,patience = 5,restore_best_weights = True,verbose = 0)

vgg16_model.compile(optimizer = keras.optimizers.RMSprop(learning_rate = 0.001) , loss = 'sparse_categorical_crossentropy' , metrics = ['accuracy'])

vgg16 = vgg16_model.fit(train_images, train_labels, batch_size = 32, epochs = 20, callbacks = [early_stopping])
# Out:
# Number of layers in Inception: 20
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 5)                 2565
#
# =================================================================
# Total params: 14,717,253
# Trainable params: 4,722,181
# Non-trainable params: 9,995,072
# _________________________________________________________________
# Epoch 1/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9226WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 3590s 2s/step - loss: 0.2409 - accuracy: 0.9226
# Epoch 2/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9431WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 681s 364ms/step - loss: 0.1598 - accuracy: 0.9431
# Epoch 3/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9511WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 4024s 2s/step - loss: 0.1403 - accuracy: 0.9511
# Epoch 4/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9582WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 622s 332ms/step - loss: 0.1262 - accuracy: 0.9582
# Epoch 5/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9615WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 649s 346ms/step - loss: 0.1149 - accuracy: 0.9615
# Epoch 6/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 0.9674WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 663s 354ms/step - loss: 0.1021 - accuracy: 0.9674
# Epoch 7/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9705WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 1762s 941ms/step - loss: 0.0924 - accuracy: 0.9705
# Epoch 8/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9734WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 442s 236ms/step - loss: 0.0847 - accuracy: 0.9734
# Epoch 9/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9764 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 19932s 11s/step - loss: 0.0783 - accuracy: 0.9764
# Epoch 10/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9786WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 544s 291ms/step - loss: 0.0704 - accuracy: 0.9786
# Epoch 11/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9817WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 564s 301ms/step - loss: 0.0631 - accuracy: 0.9817
# Epoch 12/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9828WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 636s 340ms/step - loss: 0.0574 - accuracy: 0.9828
# Epoch 13/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9848WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 441s 235ms/step - loss: 0.0508 - accuracy: 0.9848
# Epoch 14/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9859WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 436s 233ms/step - loss: 0.0474 - accuracy: 0.9859
# Epoch 15/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9874WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 437s 233ms/step - loss: 0.0444 - accuracy: 0.9874
# Epoch 16/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9881WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 437s 233ms/step - loss: 0.0403 - accuracy: 0.9881
# Epoch 17/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9888WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 438s 234ms/step - loss: 0.0408 - accuracy: 0.9888
# Epoch 18/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9900WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 436s 233ms/step - loss: 0.0348 - accuracy: 0.9900
# Epoch 19/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9905WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 436s 233ms/step - loss: 0.0333 - accuracy: 0.9905
# Epoch 20/20
# 1873/1873 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,accuracy
# 1873/1873 [==============================] - 437s 234ms/step - loss: 0.0325 - accuracy: 0.9906

# %%
vgg16_predictions = vgg16_model.predict(test_images)
vgg16_predictions = np.argmax(vgg16_predictions,axis = 1)
# Out:
# 523/523 [==============================] - 87s 164ms/step

# %%
vgg16_accuracy = vgg16_model.evaluate(test_images, test_labels, verbose = 0) 
print('Test accuracy:', vgg16_accuracy[1])
# Out:
# Test accuracy: 0.8957312107086182

# %%
cm = confusion_matrix(test_labels, vgg16_predictions)
sns.heatmap(cm,cmap = 'Blues',annot = True, xticklabels = class_names, yticklabels = class_names)
plt.show()

# %%
def scores(cm):
    p = {}
    r = {}
    f1 = {}
    
    for i in range(len(cm)):
        p[i] = cm[i,i] / sum(cm[:,i])
        r[i] = cm[i,i] / sum(cm[i,:])
        f1[i] = 2 * (cm[i,i] / sum(cm[:,i])) * (cm[i,i]/sum(cm[i,:])) / ((cm[i,i] / sum(cm[:,i])) + (cm[i,i]/sum(cm[i,:])))
    
    return p,r,f1

# %%
precision, recall, f1_score = scores(cm)

# %%
Evaluation = {
    'Precision' : precision,
    'Recall' : recall,
    'F1 Score' : f1_score
}

Result = pd.DataFrame(Evaluation)

Result
# Out:
#    Precision    Recall  F1 Score
# 0   0.922831  0.863685  0.892279
# 1   0.871896  0.927777  0.898969

# %%
vgg16_model.save("vgg16_model.h5")
